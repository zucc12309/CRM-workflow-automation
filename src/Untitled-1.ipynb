# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sales=pd.read_csv('/Users/priyanshupatel/Documents/GitHub/personal/python/sales_data.csv', parse_dates=['Date'])

# %%
sales.head(5)
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales.shape
# Out:
# (113036, 18)

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[us]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  str
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  str
#  6   Customer_Gender   113036 non-null  str
#  7   Country           113036 non-null  str
#  8   State             113036 non-null  str
#  9   Product_Category  113036 non-null  str
#  10  Sub_Category      113036 non-null  str
#  11  Product           113036 non-null  str
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
sales[['Customer_Age','Order_Quantity','Unit_Cost','Unit_Price','Profit','Cost','Revenue']].describe()
# Out:
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# std        11.021936        9.561857     549.835483     922.071219
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# 50%        35.000000       10.000000       9.000000      24.000000
# 75%        43.000000       20.000000      42.000000      70.000000
# max        87.000000       32.000000    2171.000000    3578.000000
#
#               Profit           Cost        Revenue
# count  113036.000000  113036.000000  113036.000000
# mean      285.051665     469.318695     754.370360
# std       453.887443     884.866118    1309.094674
# min       -30.000000       1.000000       2.000000
# 25%        29.000000      28.000000      63.000000
# 50%       101.000000     108.000000     223.000000
# ...

# %%
sales['Unit_Cost'].describe()
sales['Unit_Cost'].mean()
sales['Unit_Cost'].median()

# %%
sales['Unit_Cost'].plot(kind='box', figsize=(10, 4))
# Out:
# <Axes: >

# %%
sales['Unit_Cost'].plot(kind='density', figsize=(10, 4))
# Out:
# <Axes: ylabel='Density'>

# %%
ax=sales['Unit_Cost'].plot(kind='density', figsize=(10, 4))
ax.axvline(sales['Unit_Cost'].mean(),color='red', linestyle='--')
ax.axvline(sales['Unit_Cost'].median(), color='green', linestyle='--')

# %%
ax=sales['Unit_Cost'].plot(kind='hist',figsize=(10,4))
ax.set_xlabel('Unit Cost')
ax.set_ylabel('Frequency')
ax.set_title('Distribution of Unit Cost')
# Out:
# Text(0.5, 1.0, 'Distribution of Unit Cost')

# %%
sales['Age_Group'].value_counts()
# Out:
# Age_Group
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: count, dtype: int64

# %%
sales['Age_Group'].value_counts().plot(kind='pie',figsize=(6,6), autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
df=pd.read_excel('/Users/priyanshupatel/Documents/GitHub/personal/python/Nomura_Raw_Extended.xlsx',sheet_name='Raw_Data',header=2)

# %%
df.head()
# Out:
#          client_name   analyst_nm REGION  meetings_cnt  events_attended  \
# 0          dws group  ravi sharma   EMEA           8.0              6.0
# 1          Schroders  Ankit Mehta   APAC          10.0              7.0
# 2  Alpine Macro Fund  Ravi Sharma   AMER           NaN              0.0
# 3      Brevan Howard  Karan Patel   APAC           NaN              5.0
# 4    Pershing Square   Neha Joshi   APAC           NaN              NaN
#
#    reports_read revenue_usd mifid_expiry_dt client_tier last_contact_dt  \
# 0          44.0      207561      2026-08-08        Gold      22/01/2026
# 1          23.0      133667      2026-08-28        Gold      04/02/2026
# 2          60.0      264422      2026-07-31        Gold      10/01/2026
# 3          15.0      219258      2026-11-08        Gold      31/03/2026
# 4           NaN      208710      2025-12-26        Gold      12/03/2026
#
#                  notes_col internal_flag
# 0                      NaN           NaN
# ...

# %%
df_clean=df.drop(['notes_col','internal_flag'], axis=1)
df_clean.tail(10)
# Out:
#        client_name   analyst_nm REGION  meetings_cnt  events_attended  \
# 119      Man Group  Ravi Sharma   AMER           1.0              1.0
# 120    Third Point  Karan Patel   APAC           5.0              7.0
# 121   State Street  Ankit Mehta   EMEA          18.0              4.0
# 122  Baupost Group  Karan Patel   AMER          15.0              1.0
# 123   Delta One AM   Neha Joshi   APAC          14.0              5.0
# 124  Moore Capital   Neha Joshi   EMEA          19.0              6.0
# 125    dummy_entry       System    NaN           0.0              0.0
# 126       Vanguard   Neha Joshi   EMEA           3.0              7.0
# 127      Nordea AM  Karan Patel   APAC           NaN              NaN
# 128    TEST CLIENT       System    NaN           0.0              0.0
#
#      reports_read revenue_usd mifid_expiry_dt client_tier last_contact_dt
# 119          59.0       98771      2026-05-29    standard      26/03/2026
# ...

# %%
df_clean.describe()
# Out:
#        meetings_cnt  events_attended  reports_read
# count    111.000000       120.000000    120.000000
# mean      10.351351         3.858333     30.333333
# std        6.296678         2.714096     17.408746
# min        0.000000         0.000000      0.000000
# 25%        5.000000         1.000000     15.750000
# 50%       10.000000         4.000000     30.500000
# 75%       15.000000         6.000000     44.250000
# max       22.000000         8.000000     60.000000

# %%
df_clean.shape
# Out:
# (129, 10)

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   client_name      129 non-null    str
#  1   analyst_nm       129 non-null    str
#  2   REGION           124 non-null    str
#  3   meetings_cnt     111 non-null    float64
#  4   events_attended  120 non-null    float64
#  5   reports_read     120 non-null    float64
#  6   revenue_usd      120 non-null    object
#  7   mifid_expiry_dt  124 non-null    str
#  8   client_tier      124 non-null    str
#  9   last_contact_dt  124 non-null    str
# dtypes: float64(3), object(1), str(6)
# memory usage: 10.2+ KB

# %%
df_clean.isnull()
df_clean.dtypes
df_clean.isnull().sum()
df_clean.duplicated().sum()
# Out:
# np.int64(15)

# %%
df_clean[df_clean.isnull().any(axis=1)]
# Out:
#               client_name   analyst_nm REGION  meetings_cnt  events_attended  \
# 2       Alpine Macro Fund  Ravi Sharma   AMER           NaN              0.0
# 3           Brevan Howard  Karan Patel   APAC           NaN              5.0
# 4         Pershing Square   Neha Joshi   APAC           NaN              NaN
# 8    Generali Investments  Karan Patel   AMER          20.0              1.0
# 14       internal account       System    NaN           0.0              0.0
# 20      Capula Investment   Priya Nair   APAC           NaN              2.0
# 21             Apex Macro  Ankit Mehta   EMEA          19.0              5.0
# 31             Soros Fund   Neha Joshi   EMEA           NaN              NaN
# 36           TEST_ACC_002       System    NaN           0.0              0.0
# 45           Winton Group  Ankit Mehta   AMER           9.0              4.0
# 46                 Nuveen  Ravi Sharma   AMER           NaN              NaN
# ...

# %%
df_clean.columns.to_list()
# Out:
# ['client_name',
#  'analyst_nm',
#  'REGION',
#  'meetings_cnt',
#  'events_attended',
#  'reports_read',
#  'revenue_usd',
#  'mifid_expiry_dt',
#  'client_tier',
#  'last_contact_dt']

# %%
df_clean[['client_name','revenue_usd']].dtypes
# Out:
# client_name       str
# revenue_usd    object
# dtype: object

# %%
df_clean[['client_name','revenue_usd']].info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   client_name  129 non-null    str
#  1   revenue_usd  120 non-null    object
# dtypes: object(1), str(1)
# memory usage: 2.1+ KB

# %%
df_clean.isnull().sum()
# Out:
# client_name         0
# analyst_nm          0
# REGION              5
# meetings_cnt       18
# events_attended     9
# reports_read        9
# revenue_usd         9
# mifid_expiry_dt     5
# client_tier         5
# last_contact_dt     5
# dtype: int64

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(15)

# %%
df_clean['client_tier'].value_counts()
# Out:
# client_tier
# Gold        41
# Platinum    35
# Standard    29
# platinum     4
# gold         4
# STANDARD     3
# PLATINUM     3
# GOLD         3
# standard     2
# Name: count, dtype: int64

# %%
df_clean=df_clean[~df_clean['client_name'].str.contains('test|dummy|sample|internal|system',case=False, na=False)]

# %%
df_clean=df_clean.drop_duplicates(subset=['client_name','analyst_nm'],keep='first')

# %%
df_clean.head()
# Out:
#          client_name   analyst_nm REGION  meetings_cnt  events_attended  \
# 0          dws group  ravi sharma   EMEA           8.0              6.0
# 1          Schroders  Ankit Mehta   APAC          10.0              7.0
# 2  Alpine Macro Fund  Ravi Sharma   AMER           NaN              0.0
# 3      Brevan Howard  Karan Patel   APAC           NaN              5.0
# 4    Pershing Square   Neha Joshi   APAC           NaN              NaN
#
#    reports_read revenue_usd mifid_expiry_dt client_tier last_contact_dt
# 0          44.0      207561      2026-08-08        Gold      22/01/2026
# 1          23.0      133667      2026-08-28        Gold      04/02/2026
# 2          60.0      264422      2026-07-31        Gold      10/01/2026
# 3          15.0      219258      2026-11-08        Gold      31/03/2026
# 4           NaN      208710      2025-12-26        Gold      12/03/2026

# %%
df_clean['client_name']=df_clean['client_name'].str.strip().str.title()
df_clean['analyst_nm']=df_clean['analyst_nm'].str.strip().str.title()

# %%
df_clean.shape
# Out:
# (108, 10)

# %%
df_clean['client_tier'].unique()
# Out:
# <StringArray>
# [    'Gold', 'Standard', 'Platinum', 'STANDARD', 'platinum', 'PLATINUM',
#      'GOLD',     'gold', 'standard']
# Length: 9, dtype: str

# %%
df_clean['client_tier']=df_clean['client_tier'].str.strip().str.title()

# %%
df_clean['client_tier'].unique()
# Out:
# <StringArray>
# ['Gold', 'Standard', 'Platinum']
# Length: 3, dtype: str

# %%
df_clean.dtypes
# Out:
# client_name            str
# analyst_nm             str
# REGION                 str
# meetings_cnt       float64
# events_attended    float64
# reports_read       float64
# revenue_usd        float64
# mifid_expiry_dt        str
# client_tier            str
# last_contact_dt        str
# dtype: object

# %%
df_clean['revenue_usd']=pd.to_numeric(df_clean['revenue_usd'], errors='coerce')
df_clean.head()
# Out:
#          client_name   analyst_nm REGION  meetings_cnt  events_attended  \
# 0          Dws Group  Ravi Sharma   EMEA           8.0              6.0
# 1          Schroders  Ankit Mehta   APAC          10.0              7.0
# 2  Alpine Macro Fund  Ravi Sharma   AMER           NaN              0.0
# 3      Brevan Howard  Karan Patel   APAC           NaN              5.0
# 4    Pershing Square   Neha Joshi   APAC           NaN              NaN
#
#    reports_read  revenue_usd mifid_expiry_dt client_tier last_contact_dt
# 0          44.0     207561.0      2026-08-08        Gold      22/01/2026
# 1          23.0     133667.0      2026-08-28        Gold      04/02/2026
# 2          60.0     264422.0      2026-07-31        Gold      10/01/2026
# 3          15.0     219258.0      2026-11-08        Gold      31/03/2026
# 4           NaN     208710.0      2025-12-26        Gold      12/03/2026

# %%
df_clean['mifid_expiry_dt']=pd.to_datetime(df_clean['mifid_expiry_dt'],dayfirst=False, errors='coerce')

# %%
df_clean['REGION']=df_clean['REGION'].str.strip().str.upper()

# %%
for col in ['meetings_cnt','events_attended','reports_read']:
    df_clean[col]=df_clean[col].fillna(0).astype(int)

# %%
df_clean.to_excel('/Users/priyanshupatel/Documents/GitHub/personal/python/Nomura_Cleaned_Data.xlsx', index=False)

# %%
df_clean['revenue_usd']=df_clean['revenue_usd'].fillna(0)
